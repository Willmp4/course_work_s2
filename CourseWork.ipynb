# %%
"""
Student number : 21514586
@auth William Bruckmann 
"""
"""
Question 1:
Trying to figure oot time complexity for three questions.
"""

#Q1
#O(n)

#Q2
#O(log n)

#Q3
#O(n^^2)
# Out:
# '\nQuestion 1:\nTrying to figure out time complexity for three questions.\n'

# %%
"""
Student number : 21514586
@auth William Bruckmann 
"""
"""
This is a programme to produce the fib sequence

Question 2:
Write a python function that returns the nth Fibonacci number,
where n is an integer passed a parameter to the function.
"""

"""This function is highly inefficient and runs at 2**n, meaning its exponential"""
def fib_(n):#Takes in an int 
    if n <= 1: return n #Acts as base case,
    #Returns 1 or 0 if n is 1 or less
    else:
        return fib_(n-1) + fib_(n-2)#This is the recursive call evaluates the nth num of fib

"""This function runs at n"""

def fib(n, memo={}):#Takes in an int, init dict to store values 
    if n in memo: return memo[n]#If n is already in memo return that element of the fib sequence 
    if n <=1: return n#Acts as a base case
    else:
        memo[n] = fib(n-1, memo) + fib(n-2,memo)#Make new key in memo of the evaluation of recursive call when going up after base case
        return memo[n]

print("using no memo: ", fib_(5))
print("Using memo")
print(fib(17))
# Out:
# using no memo:  5
# Using memo
# 1597

# %%
"""
Student number : 21514586
@auth William Bruckmann 
"""
"""
Q3: 
Part A - 
    Evaluate Postfix expressions 
"""
class evalpostfix:
    def __init__(self):
        self.stack =[]
        self.top =-1
    def pop(self):
        if self.top ==-1:
            return
        else:
            self.top-= 1
            return self.stack.pop()
    def push(self, i):
        self.top+= 1
        self.stack.append(i)
 
    def central_func(self, string):
        for i in string:
            print(self.stack)
            # if the component of the list is an integer
            try:
                self.push(int(i))
            # if the component of the list is not an integer,
            # it must be an operator. Using ValueError, we can
            # evaluate components of the list other than type int
            except ValueError:
                val1 = self.pop()
                val2 = self.pop()
 
                # switch statement to perform operation
                switcher ={'+':val2 + val1, '-':val2-val1, '*':val2 * val1, '/':val2 / val1, '^':val2**val1}
                
                self.push(switcher.get(i))
        return int(self.pop())
 
print("StuNum: 2151486")
str ="20 8 - 42 16 - * 21 6 + /"
 
# splitting the given string to obtain
# integers and operators into a list
strconv = str.split(' ')
print(strconv)
obj = evalpostfix()
print(obj.central_func(strconv))
 
str ='8 3 7 * + 4 -'
 
# splitting the given string to obtain
# integers and operators into a list
strconv = str.split(' ')
print(strconv)
obj = evalpostfix()
print(obj.central_func(strconv))
                 
 
str ='16 12 + 4 * 2 /'
 
# splitting the given string to obtain
# integers and operators into a list
strconv = str.split(' ')
print(strconv)
obj = evalpostfix()
print(obj.central_func(strconv))
# Out:
# StuNum: 2151486
# ['20', '8', '-', '42', '16', '-', '*', '21', '6', '+', '/']
# []
# [20]
# [20, 8]
# [12]
# [12, 42]
# [12, 42, 16]
# [12, 26]
# [312]
# [312, 21]
# [312, 21, 6]
# [312, 27]
# 11
# ['8', '3', '7', '*', '+', '4', '-']
# []
# [8]
# [8, 3]
# [8, 3, 7]
# [8, 21]
# [29]
# [29, 4]
# 25
# ['16', '12', '+', '4', '*', '2', '/']
# []
# [16]
# [16, 12]
# [28]
# [28, 4]
# [112]
# [112, 2]
# 56

# %%
"""
Student number : 21514586
@auth William Bruckmann 
"""
OPERATORS = set(['+', '-', '*', '/', '(', ')', '^'])  # set of operators

PRIORITY = {'+':1, '-':1, '*':2, '/':2, '^':3} # dictionary having priorities 

 

def infix_to_postfix(expression): #input expression

    stack = [] # initially stack empty

    output = '' # initially output empty

    

    for ch in expression:

        if ch not in OPERATORS:  # if an operand then put it directly in postfix expression

            output+= ch

        elif ch=='(':  # else operators should be put in stack

            stack.append('(')

        elif ch==')':

            while stack and stack[-1]!= '(':

                output+=stack.pop()

            stack.pop()

        else:

            # lesser priority can't be on top on higher or equal priority    

             # so pop and put in output   

            while stack and stack[-1]!='(' and PRIORITY[ch]<=PRIORITY[stack[-1]]:

                output+=stack.pop()

            stack.append(ch)

    while stack:

        output+=stack.pop()

    return output

 

expression = "(20-8)*(42-16)/(21+6)"

print('infix expression: ',expression)

print('postfix expression: ',infix_to_postfix(expression))

"""
Answers:
Q1 : 
infix = (9+2*20-4)
PostFix = (9 2 20 * + 4 -)  

Q2:
infix expression:  4+5*7/3
postfix expression:  457*3/+

Q3:
infix expression:  (20-8)*(42-16)/(21+6)
postfix expression:  20 8-42 16-*21 6+/
"""
# Out:
# infix expression:  (20-8)*(42-16)/(21+6)
# postfix expression:  208-4216-*216+/
# '\nAnswers:\nQ1 : \ninfix = (9+2*20-4)\nPostFix = (9 2 20 * + 4 -)  \n\nQ2:\ninfix expression:  4+5*7/3\npostfix expression:  457*3/+\n\nQ3:\ninfix expression:  (20-8)*(42-16)/(21+6)\npostfix expression:  20 8-42 16-*21 6+/\n'

# %%
"""
Student number : 21514586
@auth William Bruckmann 
"""
"""
Q4:
First Implement a Stack to insert your studnet ID digit by digit in order such as 2113xxxx
Then empty your stack and insert the outout into the Queue. what will be the output if you empty the Queue? 
Demonstrate your work by showing the steps gor both Stack and Queue and screenshor of your code and output. Assuming both stack and queue are initially empty.
"""
class Stack: 
    def __init__(self):
        self.items = []#Creats stack

    def is_empty(self):
        return self.items == []#Return bool if stack is empty

    def peek(self):
        return self.items[-1]#Returns the final element is the array, or the first element in stack
        
    def push(self, item):
        self.items.append(item)#append item to stack 

    def pop(self):
        return self.items.pop()#Gets rid of end element

    def size(self):
        return len(self.items)#Return len of stack

    def display(self):
        print(self.items)#Prints all items to terminal 
        

class Queue:
    def __init__(self):
        self.items = []#This init the queue

    def is_empty(self):
        return self.items == []#return bool if queue is empty 

    def enqueue(self, item):
        self.items.insert(0, item)#Appends to the start of the list instead of the back like
        #a stack

    def size(self):
        return len(self.items)#Returns the len of the queue

    def dequeu(self):
        return self.items.pop()#pops from the end of the array

    def display(self):
        print(self.items)#Prints out all elements 

        
        
s = Stack()#Init stack
q = Queue()#Init queue 
num = "21514586"#StuNum
for i in num:#Iterates through num 
    print(f"Stack element pushed: {i}",end=" ")#Prints out the element being pushed
    s.push(i)#Push the element to s 
    s.display()#Displays stack each iteration 

for i in range(s.size()): #Goes up to the len of stack
    if not s.is_empty():#if statement for formantting 
        print(f"Stack elemnet popped {s.peek()}", end = " ")#This shows the element being popped
        s.display()#This prints out the stack as its being emptied 
    q.enqueue(s.pop())#This pushes to queue what s.pop() gets rid of
    
print("This is the stack after pop: ")#Shows the stack is empty
s.display()
print("What is outputted after queue is emptied ", end = " ")

for i in range(q.size()):
    print(q.dequeu(),end ="")#same order stack being popped. 
    #Seeing as Fifo
print()
print("StuNum: 2151486")
# Out:
# Stack element pushed: 2 ['2']
# Stack element pushed: 1 ['2', '1']
# Stack element pushed: 5 ['2', '1', '5']
# Stack element pushed: 1 ['2', '1', '5', '1']
# Stack element pushed: 4 ['2', '1', '5', '1', '4']
# Stack element pushed: 5 ['2', '1', '5', '1', '4', '5']
# Stack element pushed: 8 ['2', '1', '5', '1', '4', '5', '8']
# Stack element pushed: 6 ['2', '1', '5', '1', '4', '5', '8', '6']
# Stack elemnet popped 6 ['2', '1', '5', '1', '4', '5', '8', '6']
# Stack elemnet popped 8 ['2', '1', '5', '1', '4', '5', '8']
# Stack elemnet popped 5 ['2', '1', '5', '1', '4', '5']
# Stack elemnet popped 4 ['2', '1', '5', '1', '4']
# Stack elemnet popped 1 ['2', '1', '5', '1']
# Stack elemnet popped 5 ['2', '1', '5']
# Stack elemnet popped 1 ['2', '1']
# Stack elemnet popped 2 ['2']
# This is the stack after pop:
# []
# What is outputted after queue is emptied  68541512
# StuNum: 2151486

# %%
"""
@Auth William Bruckmann student number : 2151486    
Q5:
Linked Lists
Question 5
Write a Python program that creates an unordered, singly-linked list consisting of 8 items. Each item
in the linked list should be a number. You can use the code given in the lecture slides for your Node
and UnorderedList classes.
Add code to create an UnorderedList object, and call its add() function to add 8 items to the list. Call
the is_empty(), size() and print_list() functions to show that they work. In your logbook, show your
code and the output when you run the code.
The 8 numbers you will add them to the list should be your student ID.
Example output:
[5 marks]
Add a function called search() to your UnorderedList class in Question 5.1. This function should take
a number as a parameter and return True if the number is contained in the linked list, or False if the
number is not in the list.
Add code to your program to allow the user to enter a number, and search for the number in your
linked list. Display a message to the user indicating if the number they entered was found in the list
or not. In your logbook, include your code, and also output that shows you have tested the search
function for a number in the list and a number not in the list.
"""

class Node: # Deifining the Node class - see slide 7
    def __init__(self, init_data):
        self.data = init_data
        self.next = None

    def get_data(self):
        return self.data

    def get_next(self):
        return self.next

    def set_data(self, new_data):
        self.data = new_data

    def set_next(self, new_next):
        self.next = new_next



class UnorderedList:
    def __init__(self):
        self.head = None

    def add(self, item): # Function to add a node to the list
        temp = Node(item)#Ask for data 
        temp.set_next(self.head)
        self.head = temp

    def is_empty(self): # Returns True if the list is empty, False otherwise
        return self.head == None

    def size(self): # Returns the number of elements currently in the list
        curr = self.head#start at head 
        count = 0#return value 
        while curr != None:#while there is data 
            count += 1#incrament count by one 
            curr = curr.get_next()#go next until there is no data
        return count#return count 
    
    def print_list(self): # Prints the data values of all nodes in the list
        curr = self.head
        while curr != None:#Only search while curr has data
            print(curr.get_data(), end = ' ')#Uses .get_data to print the value at that node
            curr = curr.get_next()#goes to next node
        print()#print new line

    def search(self, item): # Returns True if item found in list, False otherwise
        current = self.head
        found = False
        while current != None and not found:
            if current.get_data() == item:
                found = True
            else:
                current = current.get_next()
        return found

    def remove(self, item): # Removes item from list; returns True if item was in list, False otherwise
        current = self.head
        previous = None
        found = False
        while not found and current != None:
            if current.get_data() == item:
                found = True
            else:
                previous = current
                current = current.get_next()
        if previous == None: # Item found at head of list
            self.head= current.get_next() # remove item from head of list
        elif found:
            previous.set_next(current.get_next()) # remove item from list
        return found

lst = UnorderedList()
#Adding the values to list
lst.add(2)
lst.add(1)
lst.add(5)
lst.add(1)
lst.add(4)
lst.add(5)
lst.add(8)
lst.add(6)

print("Init Linked list and added 2, 1, 5, 1, 4, 5, 8 ,6 ")
lst.print_list()
print("Testing is_empty() function")
print(lst.is_empty())
print("Showing the len of Liked List", lst.size())


while True:#while loop to ask user to enter a number to see
    #if its in the linked list 
    num = int(input("Please enter a number to search: "))#Takes user input 

    print(f"Yes {num} is in the list:", lst.search(num))#Return bools of if num is an elemnet of lst
    again = input("Want to search again?: ")#ask user if they want to repeat search
    if again.startswith("n"):
        break
print("student number - 21514586")
# Out:
# Init Linked list and added 2, 1, 5, 1, 4, 5, 8 ,6
# 6 8 5 4 1 5 1 2
# Testing is_empty() function
# False
# Showing the len of Liked List 8
# Yes 5 is in the list: True
# Yes 7 is in the list: False
# student number - 21514586

# %%
"""
@auth Willaim Bruckmann student number: 21514586

Question 6:
Selection sort: use your student ID as list of integers to be sorted by a selection sort algorithm. Show
the contents of the list after each pass through the list.
The list should be your 8-digit student ID.
Example: If your student ID is 21234567 then your list will be"""
lst = [2,1,5,4,5,8,6]

def selectionSort(alist):
    for fillslot in range(len(alist)-1,0,-1):
        positionOfMax=0
        for location in range(1,fillslot+1):
            if alist[location]>alist[positionOfMax]:
                positionOfMax = location
        print(f"The element switched {location} ", alist)
        temp = alist[fillslot]
        alist[fillslot] = alist[positionOfMax]
        alist[positionOfMax] = temp
        


selectionSort(lst)
print(lst)
print("student number - 21514586")
# Out:
# The element switched 6  [2, 1, 5, 4, 5, 8, 6]
# The element switched 5  [2, 1, 5, 4, 5, 6, 8]
# The element switched 4  [2, 1, 5, 4, 5, 6, 8]
# The element switched 3  [2, 1, 5, 4, 5, 6, 8]
# The element switched 2  [2, 1, 4, 5, 5, 6, 8]
# The element switched 1  [2, 1, 4, 5, 5, 6, 8]
# [1, 2, 4, 5, 5, 6, 8]
# student number - 21514586

# %%
"""Insertion sort: use your student ID as list of integers to be sorted by a insertion sort algorithm. Show
the contents of the list after each pass through the list.
The list should be your 8-digit student ID.
Example: If your student ID is 21234567 then your list will be"""
a = [2,1,5,4,5,8,6]   
print(a)
def insertion_sort(array):
    for slot in range(1, len(array)): 
        value = array[slot]
        test_slot = slot - 1
        while test_slot > -1 and array[test_slot] > value:
            array[test_slot + 1] = array[test_slot]
            test_slot = test_slot - 1
        array[test_slot + 1] = value
        print(f"The element switched {value} at index {test_slot+1} ", array)
    return array


print(insertion_sort(a))
print("student number - 2151486")
# Out:
# [2, 1, 5, 4, 5, 8, 6]
# The element switched 1 at index 0  [1, 2, 5, 4, 5, 8, 6]
# The element switched 5 at index 2  [1, 2, 5, 4, 5, 8, 6]
# The element switched 4 at index 2  [1, 2, 4, 5, 5, 8, 6]
# The element switched 5 at index 4  [1, 2, 4, 5, 5, 8, 6]
# The element switched 8 at index 5  [1, 2, 4, 5, 5, 8, 6]
# The element switched 6 at index 5  [1, 2, 4, 5, 5, 6, 8]
# [1, 2, 4, 5, 5, 6, 8]
# student number - 2151486
